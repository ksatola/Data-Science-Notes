# %% [markdown]
# ```
# From: https://github.com/ksatola
# Version: 0.0.0
#
# TODOs
# 1. https://machinelearningmastery.com/standard-machine-learning-datasets/
# ```

# %% [markdown]
# # Data Sources

# %% [markdown]
# See datasets and their additional description in the data folder.

# %%
# Connect with underlying Python code
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '../src')

# %%
from datasets import (
    get_dataset,
    add_dataset,
    add_prefix_to_list_items
)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
#pd.set_option("display.max_rows", 200)
#pd.set_option("display.max_columns", 100)
pd.set_option("display.max_columns", None)
#pd.set_option("display.max_colwidth", 200)

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Pima Indians Diabetes (input numeric, output categorical - binary)

# %%
columns = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
df = pd.read_csv('../data/pima-indians-diabetes.csv', names=columns)
df.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
df.dtypes
# Out:
# preg       int64
# plas       int64
# pres       int64
# skin       int64
# test       int64
# mass     float64
# pedi     float64
# age        int64
# class      int64
# dtype: object

# %%
# Missing values?
df.isnull().mean().value_counts()
# Out:
# 0.0    9
# dtype: int64

# %%
add_dataset(data=df, name="pima-indians-diabetes", url="../data/", type="csv", origin="This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases")

# %%
# target = 'class'
df = get_dataset('pima-indians-diabetes')
df.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %% [markdown]
# ### Titanic3 (input mixed, output categorical - binary)

# %%
# target = 'survived'
df = get_dataset('titanic3')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df = get_dataset('titanic3_aggregated')
df.head()
# Out:
#        0         1                                  2       3       4      5   \
# 0  pclass  survived                               name     sex     age  sibsp
# 1       1         1      Allen, Miss. Elisabeth Walton  female    29.0      0
# 2       1         1  Madill, Miss. Georgette Alexandra  female    15.0      0
# 3       1         1     Allison, Master. Hudson Trevor    male  0.9167      1
# 4       1         0       Allison, Miss. Helen Loraine  female     2.0      1
#
#       6       7         8        9         10    11    12  \
# 0  parch  ticket      fare    cabin  embarked  boat  body
# 1      0   24160  211.3375       B5         S     2   NaN
# 2      1   24160  211.3375       B5         S     2   NaN
# 3      2  113781    151.55  C22 C26         S    11   NaN
# 4      2  113781    151.55  C22 C26         S   NaN   NaN
#
#                                 13          14          15           16  \
# ...

# %% [markdown]
# ### Sonar (input numerical, output categorical - binary)
# The Sonar Dataset involves the prediction of whether or not an object is a mine or a rock given the strength of sonar returns at different angles. It is a binary (2-class) classification problem. The number of observations for each class is not balanced. There are 208 observations with 60 input variables and 1 output variable. The variable names are as follows:
# - Sonar returns at different angles (columns 0-59)
# - Class (M for mine and R for rock) - column 60

# %%
df = pd.read_csv('../data/sonar.csv', header=None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9       10      11      12      13      14      15      16      17  \
# 0  0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999
# 1  0.2872  0.4918  0.6552  0.6919  0.7797  0.7464  0.9444  1.0000  0.8874
# 2  0.6194  0.6333  0.7060  0.5544  0.5320  0.6479  0.6931  0.6759  0.7551
# 3  0.1264  0.0881  0.1992  0.0184  0.2261  0.1729  0.2131  0.0693  0.2281
# 4  0.4459  0.4152  0.3952  0.4256  0.4135  0.4528  0.5326  0.7306  0.6193
#
# ...

# %%
#y = df[[60]]
#X = df.drop(columns=60)
df[60]
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 203    M
# 204    M
# 205    M
# 206    M
# 207    M
# Name: 60, Length: 208, dtype: object

# %%
cols = df.columns.to_list()
cols[55:]
# Out:
# [55, 56, 57, 58, 59, 60]

# %%
# Column names should start with a letter, otherwise some libraries throw errors
cols[60] = f"{'class'}" # target (dependent variable)
cols[0:60] = add_prefix_to_list_items('v', cols[:60]) # independent variables
cols[55:]
# Out:
# ['v55', 'v56', 'v57', 'v58', 'v59', 'class']

# %%
df.columns=cols
df.sample(5)
# Out:
#          v0      v1      v2      v3      v4      v5      v6      v7      v8  \
# 185  0.0340  0.0625  0.0381  0.0257  0.0441  0.1027  0.1287  0.1850  0.2647
# 36   0.0094  0.0166  0.0398  0.0359  0.0681  0.0706  0.1020  0.0893  0.0381
# 103  0.0162  0.0253  0.0262  0.0386  0.0645  0.0472  0.1056  0.1388  0.0598
# 25   0.0201  0.0026  0.0138  0.0062  0.0133  0.0151  0.0541  0.0210  0.0505
# 184  0.0269  0.0383  0.0505  0.0707  0.1313  0.2103  0.2263  0.2524  0.3595
#
#          v9     v10     v11     v12     v13     v14     v15     v16     v17  \
# 185  0.4117  0.5245  0.5341  0.5554  0.3915  0.2950  0.3075  0.3021  0.2719
# 36   0.1328  0.1303  0.0273  0.0644  0.0712  0.1204  0.0717  0.1224  0.2349
# 103  0.1334  0.2969  0.4754  0.5677  0.5690  0.6421  0.7487  0.8999  1.0000
# 25   0.1097  0.0841  0.0942  0.1204  0.0420  0.0031  0.0162  0.0624  0.2127
# 184  0.5915  0.6675  0.5679  0.5175  0.3334  0.2002  0.2856  0.2937  0.3424
#
# ...

# %%
add_dataset(data=df, name="sonar", url="../data/", type="csv", origin="The Sonar Dataset involves the prediction of whether or not an object is a mine or a rock given the strength of sonar returns at different angles: https://archive.ics.uci.edu/ml/datasets/Connectionist+Bench+(Sonar,+Mines+vs.+Rocks)")

# %%
# target = 'class'
df = get_dataset('sonar')
df.head()
# Out:
#        v0      v1      v2      v3      v4      v5      v6      v7      v8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        v9     v10     v11     v12     v13     v14     v15     v16     v17  \
# 0  0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999
# 1  0.2872  0.4918  0.6552  0.6919  0.7797  0.7464  0.9444  1.0000  0.8874
# 2  0.6194  0.6333  0.7060  0.5544  0.5320  0.6479  0.6931  0.6759  0.7551
# 3  0.1264  0.0881  0.1992  0.0184  0.2261  0.1729  0.2131  0.0693  0.2281
# 4  0.4459  0.4152  0.3952  0.4256  0.4135  0.4528  0.5326  0.7306  0.6193
#
# ...

# %% [markdown]
# ### Breast Cancer Categorical Dataset (input categorical, output categorical - binary)
#
# The [Breast Cancer Categorical Dataset](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer) dataset classifies breast cancer patient data as either a recurrence or no recurrence of cancer. There are 286 examples and nine input variables. All nine input variables are categorical. It is a **binary classification problem**. A naive model can achieve an accuracy of 70% on this dataset. A good score is about 76% +/- 3%.

# %%
cols = ['age', 'menopause', 'tumor-size', 'inv-nodes', 'node-caps', 'deg-malig', 'breast', 'breast-quad', 'irradiat', 'class']
df = pd.read_csv('../data/breast-cancer.data', names=cols)
df.head()
# Out:
#        age  menopause tumor-size inv-nodes node-caps deg-malig   breast  \
# 0  '40-49'  'premeno'    '15-19'     '0-2'     'yes'       '3'  'right'
# 1  '50-59'     'ge40'    '15-19'     '0-2'      'no'       '1'  'right'
# 2  '50-59'     'ge40'    '35-39'     '0-2'      'no'       '2'   'left'
# 3  '40-49'  'premeno'    '35-39'     '0-2'     'yes'       '3'  'right'
# 4  '40-49'  'premeno'    '30-34'     '3-5'     'yes'       '2'   'left'
#
#   breast-quad irradiat                   class
# 0   'left_up'     'no'     'recurrence-events'
# 1   'central'     'no'  'no-recurrence-events'
# 2  'left_low'     'no'     'recurrence-events'
# 3  'left_low'    'yes'  'no-recurrence-events'
# 4  'right_up'     'no'     'recurrence-events'

# %%
df.dtypes
# Out:
# age            object
# menopause      object
# tumor-size     object
# inv-nodes      object
# node-caps      object
# deg-malig      object
# breast         object
# breast-quad    object
# irradiat       object
# class          object
# dtype: object

# %%
# Remove '' from all columns
for col in cols:
    df[col] = df[col].map(lambda x: str(x).rstrip("'").lstrip("'"))

# %%
df.to_csv("../data/breast-cancer.csv", index=False)

# %%
add_dataset(data=df, name="breast-cancer", url="../data/", type="csv", origin="Breast cancer patient data as either a recurrence or no recurrence of cancer")
# Out:
# dataset.py | 74 | add_dataset | 28-Sep-20 21:53:44 | INFO: Dataset name already exists

# %%
# target = 'class'
df = get_dataset('breast-cancer')
df.head()
# Out:
#      age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0  40-49   premeno      15-19       0-2       yes          3  right
# 1  50-59      ge40      15-19       0-2        no          1  right
# 2  50-59      ge40      35-39       0-2        no          2   left
# 3  40-49   premeno      35-39       0-2       yes          3  right
# 4  40-49   premeno      30-34       3-5       yes          2   left
#
#   breast-quad irradiat                 class
# 0     left_up       no     recurrence-events
# 1     central       no  no-recurrence-events
# 2    left_low       no     recurrence-events
# 3    left_low      yes  no-recurrence-events
# 4    right_up       no     recurrence-events

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Boston Housing (input numerical, output numerical)

# %% [markdown]
# ```
# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per $10,000
# PTRATIO - pupil-teacher ratio by town
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT - % lower status of the population
# MEDV - Median value of owner-occupied homes in $1000's
# ```

# %%
df = pd.read_csv('../data/boston_housing.csv')
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
add_dataset(data=df, name="boston_housing", url="../data/", type="csv", origin="Housing in the area of Boston Mass")
# Out:
# dataset.py | 65 | add_dataset | 26-Sep-20 17:36:13 | ERROR: Dataset file already exists: ../data/boston_housing.csv

# %%
# target = 'medv'
df = get_dataset('boston_housing')
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ### Multicollinearity (input numerical, output numerical)
# ```
# independent variables (physical activity, body fat percentage, weight, and the interaction between weight and body fat)
# standardised versions of inependent variables 9%Fat S, Weight S, Activity S)
# the dependent variable (bone mineral density of the femoral neck)
# ```

# %%
#cols = ['age', 'menopause', 'tumor-size', 'inv-nodes', 'node-caps', 'deg-malig', 'breast', 'breast-quad', 'irradiat', 'class']
df = pd.read_csv('../data/MulticollinearityExample.csv')
df.head()
# Out:
#    Femoral Neck  %Fat  Weight kg  Activity    %Fat S   Weight S   Activity S
# 0         0.934  25.3  52.163126   3508.44 -3.265217  -1.765066   946.450435
# 1         0.888  29.3  61.801964   2773.54  0.734783   7.873772   211.550435
# 2         0.933  37.7  93.440034   1738.97  9.134783  39.511842  -823.019565
# 3         0.757  32.8  59.874197   1665.29  4.234783   5.946005  -896.699565
# 4         1.031  24.6  50.348756   3982.95 -3.965217  -3.579436  1420.960435

# %%
#add_dataset(data=df, name="multicollinearity", url="../data/", type="csv", origin="Multicollinearity Example: Predicting Bone Density in the Femur")

# %% [markdown]
# ### Heteroscedasticity (input numerical, output numerical)
# ```
#  Accident as the dependent variable and Population for the independent variable
# ```

# %%
df = pd.read_csv('../data/Heteroscedasticity.csv')
df.head()
# Out:
#    Accidents  AccidentRate     Population    Weight
# 0         20      0.000135  147603.989041  0.000007
# 1         38      0.000062  611903.157933  0.000002
# 2         17      0.000120  141304.462040  0.000007
# 3         16      0.000078  204849.503667  0.000005
# 4         20      0.000131  152426.475662  0.000007

# %%
#add_dataset(data=df, name="heteroscedasticity", url="../data/", type="csv", origin="Heteroscedasticity Example: Number of automobile accidents by the population of towns and cities")

# %% [markdown]
# ## Random data to demonstrate data mining problems
# 101 columns of data, and each one contains 30 rows of entirely random data. The first column (C1) will be the dependent variable, and the other 100 columns are potential independent variables.

# %%
df = pd.read_csv('../data/Random_data.csv')
df.head()
# Out:
#          C1        C2        C3        C4        C5        C6        C7  \
# 0 -0.635418 -0.579130 -0.676321 -0.604970 -0.625573 -0.076850 -0.117557
# 1  0.789120 -0.029943 -0.030433  1.015895  0.402405 -0.967939 -0.416510
# 2  1.605939  1.049132  0.162055 -0.516985  0.109957  0.458772 -0.531809
# 3  0.339110  1.150962  1.701447 -0.129415  1.278501 -0.960337 -0.075751
# 4  0.422166 -0.557173 -0.669985 -0.148770 -0.791304  0.318879 -0.946038
#
#          C8        C9       C10       C11       C12       C13       C14  \
# 0  0.052531 -2.148799 -0.708732 -2.234344  0.333315 -1.420903 -0.617101
# 1  0.046567  0.103896 -0.218818  1.674899 -0.019631  0.633296 -0.371775
# 2  2.613801 -1.506208  0.184250  1.186120 -0.643803 -1.846327  0.749382
# 3 -0.864351 -1.610699 -1.797953  0.034645  2.174595 -0.064133 -0.957068
# 4  0.002033 -1.048584 -0.956571 -0.533858 -1.115181  0.471457 -0.860000
#
#         C15       C16       C17       C18       C19       C20       C21  \
# ...

# %%
#add_dataset(data=df, name="random", url="../data/", type="csv", origin="Random data")
