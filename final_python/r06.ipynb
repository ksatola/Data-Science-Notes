# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.experimental import (
    enable_iterative_imputer,
)
from sklearn import (
    ensemble,
    impute,
    model_selection,    
    preprocessing,
    tree,
)

url = (
    "http://biostat.mc.vanderbilt.edu/"
    "wiki/pub/Main/DataSets/titanic3.xls"
)
df = pd.read_excel(url)
orig_df = df

# %%
def tweak_titanic(df):
    df = df.drop(
        columns=[
            "name",
            "ticket",
            "home.dest",
            "boat",
            "body",
            "cabin",
        ]
    ).pipe(pd.get_dummies, drop_first=True)
    return df

def get_train_test_X_y(
    df, y_col, size=0.3, std_cols=None
):
    y = df[y_col]
    X = df.drop(columns=y_col)
    X_train, X_test, y_train, y_test = model_selection.train_test_split(
        X, y, test_size=size, random_state=42
    )
    cols = X.columns
    num_cols = [
        "pclass",
        "age",
        "sibsp",
        "parch",
        "fare",
    ]
    fi = impute.IterativeImputer()
    X_train.loc[
        :, num_cols
    ] = fi.fit_transform(X_train[num_cols])
    X_test.loc[:, num_cols] = fi.transform(
        X_test[num_cols]
    )

    if std_cols:
        std = preprocessing.StandardScaler()
        X_train.loc[
            :, std_cols
        ] = std.fit_transform(
            X_train[std_cols]
        )
        X_test.loc[
            :, std_cols
        ] = std.transform(X_test[std_cols])

    return X_train, X_test, y_train, y_test

ti_df = tweak_titanic(orig_df)
std_cols = "pclass,age,sibsp,fare".split(",")
X_train, X_test, y_train, y_test = get_train_test_X_y(
    ti_df, "survived", std_cols=std_cols
)

X = pd.concat([X_train, X_test])
y = pd.concat([y_train, y_test])
# Out:
# c:\users\admin\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# c:\users\admin\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# c:\users\admin\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# c:\users\admin\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
X.shape
# Out:
# (1309, 8)

# %%
X.describe().iloc[:, [0, -1]]
# Out:
#             pclass   embarked_S
# count  1309.000000  1309.000000
# mean     -0.012831     0.698243
# std       0.995822     0.459196
# min      -1.551881     0.000000
# 25%      -0.363317     0.000000
# 50%       0.825248     1.000000
# 75%       0.825248     1.000000
# max       0.825248     1.000000

# %%
X.iloc[[1, 4], -3:]
# Out:
#      sex_male  embarked_Q  embarked_S
# 677         1           0           1
# 864         0           0           1

# %%
X.loc[[677, 864], "sex_male":]
# Out:
#      sex_male  embarked_Q  embarked_S
# 677         1           0           1
# 864         0           0           1

# %%
fig, ax = plt.subplots(figsize=(6, 4))
X.fare.plot(kind="hist", ax=ax)
ax.set_ylabel("Częstość")
#fig.savefig("images/mlpr_0601.png", dpi=300)
# Out:
# Text(0, 0.5, 'Częstość')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
mask = y_train == 1
ax = sns.distplot(X_train[mask].fare, label='przeżyli')
ax = sns.distplot(X_train[~mask].fare, label='zginęli')
ax.set_xlabel("Cena biletu")
ax.set_xlim(-1.5, 1.5)
ax.legend()
#fig.savefig('images/mlpr_0602.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6, 4))
X.plot.scatter(
    x="age", y="fare", ax=ax, alpha=0.3
)
plt.xlabel("Wiek")
plt.ylabel("Cena biletu")
#fig.savefig("images/mlpr_0603.png", dpi=300)
# Out:
# Text(0, 0.5, 'Cena biletu')

# %%
X.age.corr(X.fare)
# Out:
# 0.17719980495717763

# %%
from yellowbrick.features import (
    JointPlotVisualizer,
)
fig, ax = plt.subplots(figsize=(6, 6))
jpv = JointPlotVisualizer(
    feature="age", target="fare"
)
jpv.fit(X["age"], X["fare"])
jpv.poof()
#fig.savefig("images/mlpr_0604.png", dpi=300)

# %%
from seaborn import jointplot
fig, ax = plt.subplots(figsize=(6, 6))
new_df = X.copy()
new_df["target"] = y
p = jointplot(
    "age", "fare", data=new_df, kind="reg"
)
plt.xlabel("Wiek")
plt.ylabel("Cena biletu")
#p.savefig("images/mlpr_0605.png", dpi=300)
# Out:
# Text(29.0, 0.5, 'Cena biletu')

# %%
from seaborn import pairplot
fig, ax = plt.subplots(figsize=(6, 6))
new_df = X.copy()
new_df["target"] = y
vars = ["pclass", "age", "fare"]
p = pairplot(
    new_df, vars=vars, hue="target", kind="reg"
)
labels = ["Klasa", "Wiek", "Cena biletu"]
for i in range(3):
    p.axes[2][i].set_xlabel(labels[i])
    p.axes[i][0].set_ylabel(labels[i])
p._legend.remove()
p.add_legend(title="Cel")
#p.savefig("images/mlpr_0606.png", dpi=300)

# %%
from seaborn import boxplot
fig, ax = plt.subplots(figsize=(8, 6))
new_df = X.copy()
new_df["target"] = y
boxplot(x="target", y="age", data=new_df)
plt.xlabel("Cel")
plt.ylabel("Wiek")
#fig.savefig("images/mlpr_0607.png", dpi=300)
# Out:
# Text(0, 0.5, 'Wiek')

# %%
from seaborn import violinplot
fig, ax = plt.subplots(figsize=(8, 6))
new_df = X.copy()
new_df["target"] = y
violinplot(
    x="target", y="sex_male", data=new_df
)
plt.xlabel("Cel")
plt.ylabel("Mężczyzna")
#fig.savefig("images/mlpr_0608.png", dpi=300)
# Out:
# Text(0, 0.5, 'Mężczyzna')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
(
    X.assign(
        age_bin=pd.qcut(
            X.age, q=10, labels=False
        ),
        class_bin=pd.cut(
            X.pclass, bins=3, labels=False
        ),
    )
    .groupby(["age_bin", "class_bin"])
    .size()
    .unstack()
    .pipe(lambda df: df.div(df.sum(1), axis=0))
    .plot.bar(
        stacked=True,
        width=1,
        ax=ax,
        cmap="viridis",
    )
    .legend(bbox_to_anchor=(1, 1))
)
ax.set_xlabel("Przedział wiekowy")
#fig.savefig(
#     "image/mlpr_0609.png",
#     dpi=300,
#     bbox_inches="tight",
# )
# Out:
# Text(0.5, 0, 'Przedział wiekowy')

# %%
from yellowbrick.features import Rank2D
fig, ax = plt.subplots(figsize=(6, 6))
pcv = Rank2D(
    features=X.columns, algorithm="pearson", title="Korelacja Pearsona 8 cech"
)
pcv.fit(X, y)
pcv.transform(X)
pcv.poof()
# fig.savefig(
#     "images/mlpr_0610.png",
#     dpi=300,
#     bbox_inches="tight",
#)

# %%
from seaborn import heatmap
fig, ax = plt.subplots(figsize=(8, 8))
ax = heatmap(
    X.corr(),
    fmt=".2f",
    annot=True,
    ax=ax,
    cmap="RdBu_r",
    vmin=-1,
    vmax=1,
)
ax.set_title("Korelacja 8 cech")
# fig.savefig(
#     "images/mlpr_0611.png",
#     dpi=300,
#     bbox_inches="tight",
# )
# Out:
# Text(0.5, 1, 'Korelacja 8 cech')

# %%
X.corr().iloc[:, :2]
# Out:
#               pclass       age
# pclass      1.000000 -0.439704
# age        -0.439704  1.000000
# sibsp       0.060832 -0.292056
# parch       0.018322 -0.176447
# fare       -0.558827  0.177200
# sex_male    0.124617  0.065004
# embarked_Q  0.230491 -0.053904
# embarked_S  0.096335 -0.045361

# %%
def correlated_columns(df, threshold=0.95):
    return (
        df.corr()
        .pipe(
            lambda df1: pd.DataFrame(
                np.tril(df1, k=-1),
                columns=df.columns,
                index=df.columns,
            )
        )
        .stack()
        .rename("pearson")
        .pipe(
            lambda s: s[
                s.abs() > threshold
            ].reset_index()
        )
        .query("level_0 not in level_1")
    )
correlated_columns(X)
# Out:
# Empty DataFrame
# Columns: [level_0, level_1, pearson]
# Index: []

# %%
>>> agg = (
...     df.groupby("cabin")
...     .agg("min,max,mean,sum".split(","))
...     .reset_index()
... )
>>> agg.columns = [
...     "_".join(c).strip("_")
...     for c in agg.columns.values
... ]
>>> agg_df = df.merge(agg, on="cabin")

# %%
c_df = correlated_columns(agg_df.select_dtypes('number'))
c_df.style.format({"pearson": "{:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_0a5c1928_3e87_11ea_adb4_000c2983e3ed" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >level_0</th>        <th class="col_heading level0 col1" >level_1</th>        <th class="col_heading level0 col2" >pearson</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row0" class="row_heading level0 row0" >3</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow0_col0" class="data row0 col0" >pclass_mean</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow0_col1" class="data row0 col1" >pclass</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow0_col2" class="data row0 col2" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row1" class="row_heading level0 row1" >4</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow1_col0" class="data row1 col0" >pclass_mean</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow1_col1" class="data row1 col1" >pclass_min</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow1_col2" class="data row1 col2" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row2" class="row_heading level0 row2" >5</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow2_col0" class="data row2 col0" >pclass_mean</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow2_col1" class="data row2 col1" >pclass_max</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow2_col2" class="data row2 col2" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row3" class="row_heading level0 row3" >6</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow3_col0" class="data row3 col0" >sibsp_mean</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow3_col1" class="data row3 col1" >sibsp_max</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow3_col2" class="data row3 col2" >0.97</td>
#             </tr>
#             <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row4" class="row_heading level0 row4" >7</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow4_col0" class="data row4 col0" >parch_mean</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow4_col1" class="data row4 col1" >parch_min</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow4_col2" class="data row4 col2" >0.95</td>
#             </tr>
#             <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row5" class="row_heading level0 row5" >8</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow5_col0" class="data row5 col0" >parch_mean</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow5_col1" class="data row5 col1" >parch_max</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow5_col2" class="data row5 col2" >0.96</td>
#             </tr>
#             <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row6" class="row_heading level0 row6" >9</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow6_col0" class="data row6 col0" >fare_mean</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow6_col1" class="data row6 col1" >fare</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow6_col2" class="data row6 col2" >0.95</td>
#             </tr>
#             <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row7" class="row_heading level0 row7" >10</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow7_col0" class="data row7 col0" >fare_mean</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow7_col1" class="data row7 col1" >fare_max</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow7_col2" class="data row7 col2" >0.98</td>
#             </tr>
#             <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row8" class="row_heading level0 row8" >17</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow8_col0" class="data row8 col0" >body_sum</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow8_col1" class="data row8 col1" >body</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow8_col2" class="data row8 col2" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row9" class="row_heading level0 row9" >18</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow9_col0" class="data row9 col0" >body_sum</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow9_col1" class="data row9 col1" >body_min</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow9_col2" class="data row9 col2" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row10" class="row_heading level0 row10" >19</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow10_col0" class="data row10 col0" >body_sum</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow10_col1" class="data row10 col1" >body_max</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow10_col2" class="data row10 col2" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edlevel0_row11" class="row_heading level0 row11" >20</th>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow11_col0" class="data row11 col0" >body_sum</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow11_col1" class="data row11 col1" >body_mean</td>
#                         <td id="T_0a5c1928_3e87_11ea_adb4_000c2983e3edrow11_col2" class="data row11 col2" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
from yellowbrick.features import RadViz
fig, ax = plt.subplots(figsize=(6, 6))
rv = RadViz(
    classes=["zginęli", "przeżyli"],
    features=X.columns,
    title="Wykres RadViz 8 cech"
)
rv.fit(X, y)
_ = rv.transform(X)
rv.poof()
#fig.savefig("images/mlpr_0612.png", dpi=300)

# %%
from pandas.plotting import radviz
fig, ax = plt.subplots(figsize=(6, 6))
new_df = X.copy()
new_df["target"] = y
radviz(
    new_df, "target", ax=ax, colormap="PiYG"
)
ax.set_title("Wykres RadViz 8 cech")
#fig.savefig("images/mlpr_0613.png", dpi=300)
# Out:
# Text(0.5, 1.0, 'Wykres RadViz 8 cech')

# %%
from yellowbrick.features import (
    ParallelCoordinates,
)
fig, ax = plt.subplots(figsize=(6, 4))
pc = ParallelCoordinates(
    classes=["zginęli", "przeżyli"],
    features=X.columns,
    title="Współrzędne równoległe 8 cech"
)
pc.fit(X, y)
pc.transform(X)
ax.set_xticklabels(
    ax.get_xticklabels(), rotation=45
)
pc.poof()
#fig.savefig("images/mlpr_0614.png", dpi=300)

# %%
from pandas.plotting import (
    parallel_coordinates,
)
fig, ax = plt.subplots(figsize=(6, 4))
new_df = X.copy()
new_df["target"] = y
parallel_coordinates(
    new_df,
    "target",
    ax=ax,
    colormap="viridis",
    alpha=0.5,
)
ax.set_xticklabels(
    ax.get_xticklabels(), rotation=45
)
ax.set_title("Współrzędne równoległe 8 cech")
# fig.savefig(
#     "images/mlpr_0615.png",
#     dpi=300,
#     bbox_inches="tight",
# )
# Out:
# Text(0.5, 1.0, 'Współrzędne równoległe 8 cech')
