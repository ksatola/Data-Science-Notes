# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('./data/numerical_data.csv')

# %%
# Proportion of individuals in the dataset with salary reported
prop_sals = 1 - df.isnull().mean()['Salary']
prop_sals
# Out:
# 0.26222385090566436
